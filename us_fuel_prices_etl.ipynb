# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 3.0 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10

# %%
#dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# U.S. Gasoline and Diesel Retail Prices 1995-2021
csv_file = "PET_PRI_GND_DCUS_NUS_W.csv"
us_gas_price_df = pd.read_csv(csv_file)
us_gas_price_df.head()
# Out:
#          Date     A1     A2     A3     R1     R2     R3     M1     M2     M3  \
# 0  01/02/1995  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159  1.298
# 1  01/09/1995  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164  1.300
# 2  01/16/1995  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155  1.299
# 3  01/23/1995  1.132  1.110  1.226  1.083  1.068  1.165  1.177  1.165  1.296
# 4  01/30/1995  1.131  1.109  1.221  1.083  1.068  1.162  1.176  1.163  1.291
#
#       P1     P2     P3     D1
# 0  1.272  1.250  1.386  1.104
# 1  1.279  1.256  1.387  1.102
# 2  1.271  1.249  1.385  1.100
# 3  1.277  1.256  1.378  1.095
# 4  1.275  1.255  1.370  1.090

# %%
# Complete US Fuel Economy Data 2021
excel_file = "complete_us_fuel_economy/2021 FE Guide for DOE-release dates before 6-24-2021-no-sales -6-23-2021public.xlsx"
car_stats_2021 = pd.read_excel(excel_file)
car_stats_2021_clean = car_stats_2021.loc[:,["Model Year","Mfr Name","Division","City FE (Guide) - Conventional Fuel",
                                             "Hwy FE (Guide) - Conventional Fuel","Comb FE (Guide) - Conventional Fuel",
                                            "City Unadj FE - Conventional Fuel","Hwy Unadj FE - Conventional Fuel","Comb Unadj FE - Conventional Fuel",
                                            "City Unrd Adj FE - Conventional Fuel","Hwy Unrd Adj FE - Conventional Fuel","Comb Unrd Adj FE - Conventional Fuel",
                                            "Fuel Usage Desc - Conventional Fuel"]]
car_stats_2021_clean.head()
# Out:
#    Model Year             Mfr Name                  Division  \
# 0        2021                Honda                     Acura
# 1        2021         aston martin  Aston Martin Lagonda Ltd
# 2        2021         aston martin  Aston Martin Lagonda Ltd
# 3        2021  Volkswagen Group of                      Audi
# 4        2021  Volkswagen Group of                      Audi
#
#    City FE (Guide) - Conventional Fuel  Hwy FE (Guide) - Conventional Fuel  \
# 0                                   21                                  22
# 1                                   14                                  21
# 2                                   18                                  24
# 3                                   13                                  20
# 4                                   14                                  23
#
#    Comb FE (Guide) - Conventional Fuel  City Unadj FE - Conventional Fuel  \
# 0                                   21                            28.7000
# 1                                   17                            17.3588
# 2                                   20                            22.5379
# 3                                   16                            15.8765
# 4                                   17                            15.8768
#
#    Hwy Unadj FE - Conventional Fuel  Comb Unadj FE - Conventional Fuel  \
# 0                           30.2000                            29.3561
# 1                           29.2584                            21.2475
# 2                           34.2945                            26.6489
# 3                           26.0378                            19.2586
# 4                           29.6317                            20.0690
#
#    City Unrd Adj FE - Conventional Fuel  Hwy Unrd Adj FE - Conventional Fuel  \
# 0                               21.0000                              21.7131
# 1                               14.1001                              21.0816
# 2                               17.9972                              24.4274
# 3                               13.3388                              19.6687
# 4                               13.6958                              22.9342
#
#    Comb Unrd Adj FE - Conventional Fuel  \
# 0                               21.0000
# 1                               16.5693
# 2                               20.4155
# 3                               15.5977
# 4                               16.7281
#
#        Fuel Usage Desc - Conventional Fuel
# 0     Gasoline (Premium Unleaded Required)
# 1  Gasoline (Premium Unleaded Recommended)
# 2  Gasoline (Premium Unleaded Recommended)
# 3     Gasoline (Premium Unleaded Required)
# 4     Gasoline (Premium Unleaded Required)

# %%
# Complete US Fuel Economy Data 2020
excel_file = "complete_us_fuel_economy/2020 FE Guide-adds and corrections for DOE-OK for release-no-sales- 4-7-2021forpublic.xlsx"
car_stats_2020 = pd.read_excel(excel_file)
car_stats_2020_clean = car_stats_2020.loc[:,["Model Year","Mfr Name","Division","City FE (Guide) - Conventional Fuel",
                                             "Hwy FE (Guide) - Conventional Fuel","Comb FE (Guide) - Conventional Fuel",
                                            "City Unadj FE - Conventional Fuel","Hwy Unadj FE - Conventional Fuel","Comb Unadj FE - Conventional Fuel",
                                            "City Unrd Adj FE - Conventional Fuel","Hwy Unrd Adj FE - Conventional Fuel","Comb Unrd Adj FE - Conventional Fuel",
                                            "Fuel Usage Desc - Conventional Fuel"]]
car_stats_2020_clean.head()
# Out:
#    Model Year             Mfr Name                  Division  \
# 0        2020                Honda                     Acura
# 1        2020           FCA US LLC                ALFA ROMEO
# 2        2020         aston martin  Aston Martin Lagonda Ltd
# 3        2020         aston martin  Aston Martin Lagonda Ltd
# 4        2020  Volkswagen Group of                      Audi
#
#    City FE (Guide) - Conventional Fuel  Hwy FE (Guide) - Conventional Fuel  \
# 0                                   21                                  22
# 1                                   24                                  34
# 2                                   14                                  21
# 3                                   18                                  24
# 4                                   13                                  20
#
#    Comb FE (Guide) - Conventional Fuel  City Unadj FE - Conventional Fuel  \
# 0                                   21                            28.7000
# 1                                   28                            28.7000
# 2                                   17                            17.3588
# 3                                   20                            22.5379
# 4                                   16                            16.0159
#
#    Hwy Unadj FE - Conventional Fuel  Comb Unadj FE - Conventional Fuel  \
# 0                           30.2000                            29.3561
# 1                           45.7000                            34.4702
# 2                           29.2584                            21.2475
# 3                           34.2945                            26.6489
# 4                           26.8762                            19.5755
#
#    City Unrd Adj FE - Conventional Fuel  Hwy Unrd Adj FE - Conventional Fuel  \
# 0                               21.0000                              21.7131
# 1                               24.2492                              34.3275
# 2                               14.1001                              21.0816
# 3                               17.9972                              24.4274
# 4                               13.4690                              20.4562
#
#    Comb Unrd Adj FE - Conventional Fuel  \
# 0                               21.0000
# 1                               27.9406
# 2                               16.5693
# 3                               20.4155
# 4                               15.9153
#
#        Fuel Usage Desc - Conventional Fuel
# 0     Gasoline (Premium Unleaded Required)
# 1  Gasoline (Premium Unleaded Recommended)
# 2  Gasoline (Premium Unleaded Recommended)
# 3  Gasoline (Premium Unleaded Recommended)
# 4     Gasoline (Premium Unleaded Required)

# %%
# Complete US Fuel Economy Data 2019
excel_file = "complete_us_fuel_economy/2019 FE Guide-for DOE-release dates before 12-19-2019-no-sales- 12_17_2019McLarenpublic.xlsx"
car_stats_2019 = pd.read_excel(excel_file)
car_stats_2019_clean = car_stats_2019.loc[:,["Model Year","Mfr Name","Division","City FE (Guide) - Conventional Fuel",
                                             "Hwy FE (Guide) - Conventional Fuel","Comb FE (Guide) - Conventional Fuel",
                                            "City Unadj FE - Conventional Fuel","Hwy Unadj FE - Conventional Fuel","Comb Unadj FE - Conventional Fuel",
                                            "City Unrd Adj FE - Conventional Fuel","Hwy Unrd Adj FE - Conventional Fuel","Comb Unrd Adj FE - Conventional Fuel",
                                            "Fuel Usage Desc - Conventional Fuel"]]
car_stats_2019_clean.head()
# Out:
#    Model Year             Mfr Name                  Division  \
# 0        2019                Honda                     Acura
# 1        2019           FCA US LLC                ALFA ROMEO
# 2        2019         aston martin  Aston Martin Lagonda Ltd
# 3        2019  Volkswagen Group of                      Audi
# 4        2019                  BMW                       BMW
#
#    City FE (Guide) - Conventional Fuel  Hwy FE (Guide) - Conventional Fuel  \
# 0                                   21                                  22
# 1                                   24                                  34
# 2                                   18                                  25
# 3                                   23                                  31
# 4                                   25                                  32
#
#    Comb FE (Guide) - Conventional Fuel  City Unadj FE - Conventional Fuel  \
# 0                                   21                            28.7000
# 1                                   28                            28.7000
# 2                                   21                            23.1719
# 3                                   26                            28.3069
# 4                                   28                            32.2000
#
#    Hwy Unadj FE - Conventional Fuel  Comb Unadj FE - Conventional Fuel  \
# 0                           30.2000                            29.3561
# 1                           45.7000                            34.4702
# 2                           35.2592                            27.3986
# 3                           42.4085                            33.2879
# 4                           45.9000                            37.1959
#
#    City Unrd Adj FE - Conventional Fuel  Hwy Unrd Adj FE - Conventional Fuel  \
# 0                               21.0000                              21.7131
# 1                               24.2492                              34.3275
# 2                               18.4652                              25.0596
# 3                               22.9796                              30.9611
# 4                               24.9259                              31.8536
#
#    Comb Unrd Adj FE - Conventional Fuel  \
# 0                               21.0000
# 1                               27.9406
# 2                               20.9455
# 3                               25.9952
# 4                               27.6300
#
#        Fuel Usage Desc - Conventional Fuel
# 0     Gasoline (Premium Unleaded Required)
# 1  Gasoline (Premium Unleaded Recommended)
# 2  Gasoline (Premium Unleaded Recommended)
# 3  Gasoline (Regular Unleaded Recommended)
# 4  Gasoline (Premium Unleaded Recommended)

# %%
# Complete US Fuel Economy Data 2018
excel_file = "complete_us_fuel_economy/2018 FE Guide for DOE3 -all rel dates-no-sales-3-25-2019McLarenforpublic.xlsx"
car_stats_2018 = pd.read_excel(excel_file)
car_stats_2018_clean = car_stats_2018.loc[:,["Model Year","Mfr Name","Division","City FE (Guide) - Conventional Fuel",
                                             "Hwy FE (Guide) - Conventional Fuel","Comb FE (Guide) - Conventional Fuel",
                                            "City Unadj FE - Conventional Fuel","Hwy Unadj FE - Conventional Fuel","Comb Unadj FE - Conventional Fuel",
                                            "City Unrd Adj FE - Conventional Fuel","Hwy Unrd Adj FE - Conventional Fuel","Comb Unrd Adj FE - Conventional Fuel",
                                            "Fuel Usage Desc - Conventional Fuel"]]
car_stats_2018_clean.head()
# Out:
#    Model Year      Mfr Name                  Division  \
# 0        2018  aston martin  Aston Martin Lagonda Ltd
# 1        2018  aston martin  Aston Martin Lagonda Ltd
# 2        2018  aston martin  Aston Martin Lagonda Ltd
# 3        2018  aston martin  Aston Martin Lagonda Ltd
# 4        2018           BMW                      Mini
#
#    City FE (Guide) - Conventional Fuel  Hwy FE (Guide) - Conventional Fuel  \
# 0                                   15                                  21
# 1                                   18                                  24
# 2                                   13                                  21
# 3                                   14                                  21
# 4                                   24                                  32
#
#    Comb FE (Guide) - Conventional Fuel  City Unadj FE - Conventional Fuel  \
# 0                                   17                            18.8306
# 1                                   20                            22.7207
# 2                                   16                            16.5327
# 3                                   17                            17.2984
# 4                                   27                            31.3604
#
#    Hwy Unadj FE - Conventional Fuel  Comb Unadj FE - Conventional Fuel  \
# 0                           30.8924                            22.8444
# 1                           33.8295                            26.6603
# 2                           28.7057                            20.4316
# 3                           29.8618                            21.3382
# 4                           46.5690                            36.7632
#
#    City Unrd Adj FE - Conventional Fuel  Hwy Unrd Adj FE - Conventional Fuel  \
# 0                               15.1397                              20.5453
# 1                               18.1323                              24.1217
# 2                               13.4660                              20.7097
# 3                               14.0538                              21.4866
# 4                               24.3407                              32.2701
#
#    Comb Unrd Adj FE - Conventional Fuel  \
# 0                               17.1729
# 1                               20.4132
# 2                               15.9815
# 3                               16.6449
# 4                               27.3667
#
#        Fuel Usage Desc - Conventional Fuel
# 0  Gasoline (Premium Unleaded Recommended)
# 1  Gasoline (Premium Unleaded Recommended)
# 2  Gasoline (Premium Unleaded Recommended)
# 3  Gasoline (Premium Unleaded Recommended)
# 4  Gasoline (Premium Unleaded Recommended)

# %%
# Complete US Fuel Economy Data 2017
excel_file = "complete_us_fuel_economy/2017 FE Guide for DOE-release dates before 3-25-2019-no sales-9-19-2019McLarenforpublic.xlsx"
car_stats_2017 = pd.read_excel(excel_file)
car_stats_2017_clean = car_stats_2017.loc[:,["Model Year","Mfr Name","Division","City FE (Guide) - Conventional Fuel",
                                             "Hwy FE (Guide) - Conventional Fuel","Comb FE (Guide) - Conventional Fuel",
                                            "City Unadj FE - Conventional Fuel","Hwy Unadj FE - Conventional Fuel","Comb Unadj FE - Conventional Fuel",
                                            "City Unrd Adj FE - Conventional Fuel","Hwy Unrd Adj FE - Conventional Fuel","Comb Unrd Adj FE - Conventional Fuel",
                                            "Fuel Usage Desc - Conventional Fuel"]]
car_stats_2017_clean.head()
# Out:
#    Model Year             Mfr Name                  Division  \
# 0        2017                Honda                     Acura
# 1        2017           FCA US LLC                ALFA ROMEO
# 2        2017         aston martin  Aston Martin Lagonda Ltd
# 3        2017         aston martin  Aston Martin Lagonda Ltd
# 4        2017  Volkswagen Group of                      Audi
#
#    City FE (Guide) - Conventional Fuel  Hwy FE (Guide) - Conventional Fuel  \
# 0                                   21                                  22
# 1                                   24                                  34
# 2                                   12                                  18
# 3                                   10                                  16
# 4                                   14                                  22
#
#    Comb FE (Guide) - Conventional Fuel  City Unadj FE - Conventional Fuel  \
# 0                                   21                            28.7000
# 1                                   28                            28.7000
# 2                                   14                            14.7893
# 3                                   12                            12.2894
# 4                                   17                            17.2263
#
#    Hwy Unadj FE - Conventional Fuel  Comb Unadj FE - Conventional Fuel  \
# 0                           30.2000                            29.3561
# 1                           45.7000                            34.4702
# 2                           25.3011                            18.1901
# 3                           22.3680                            15.4150
# 4                           29.0421                            21.0869
#
#    City Unrd Adj FE - Conventional Fuel  Hwy Unrd Adj FE - Conventional Fuel  \
# 0                               21.0000                              21.7131
# 1                               24.2492                              34.3275
# 2                               12.1164                              18.3976
# 3                               10.1534                              16.3763
# 4                               14.4642                              21.6225
#
#    Comb Unrd Adj FE - Conventional Fuel  \
# 0                               21.0000
# 1                               27.9406
# 2                               14.3158
# 3                               12.2477
# 4                               16.9962
#
#        Fuel Usage Desc - Conventional Fuel
# 0     Gasoline (Premium Unleaded Required)
# 1  Gasoline (Premium Unleaded Recommended)
# 2  Gasoline (Premium Unleaded Recommended)
# 3  Gasoline (Premium Unleaded Recommended)
# 4  Gasoline (Premium Unleaded Recommended)

# %%
#let's merge all dataframes together from 2017-2021


frames = [car_stats_2017_clean, car_stats_2018_clean, car_stats_2019_clean,
         car_stats_2018_clean, car_stats_2018_clean]

result = pd.concat(frames)
# make sure merge is doing what we think it is by looking at counts
# result.count()
# car_stats_2017_clean.count()
# car_stats_2018_clean.count()
