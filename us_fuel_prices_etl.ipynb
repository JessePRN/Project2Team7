# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 3.0 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10

# %%
#dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# U.S. Gasoline and Diesel Retail Prices 1995-2021
csv_file = "PET_PRI_GND_DCUS_NUS_W.csv"
us_gas_price_df = pd.read_csv(csv_file)
us_gas_price_df.head()
# Out:
#          Date     A1     A2     A3     R1     R2     R3     M1     M2     M3  \
# 0  01/02/1995  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159  1.298
# 1  01/09/1995  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164  1.300
# 2  01/16/1995  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155  1.299
# 3  01/23/1995  1.132  1.110  1.226  1.083  1.068  1.165  1.177  1.165  1.296
# 4  01/30/1995  1.131  1.109  1.221  1.083  1.068  1.162  1.176  1.163  1.291
#
#       P1     P2     P3     D1
# 0  1.272  1.250  1.386  1.104
# 1  1.279  1.256  1.387  1.102
# 2  1.271  1.249  1.385  1.100
# 3  1.277  1.256  1.378  1.095
# 4  1.275  1.255  1.370  1.090

# %%
# Complete US Fuel Economy Data 2021
excel_file = "complete_us_fuel_economy/2021 FE Guide for DOE-release dates before 6-24-2021-no-sales -6-23-2021public.xlsx"
car_stats_2021 = pd.read_excel(excel_file)
car_stats_2021.head()
# Out:
#    Model Year             Mfr Name                  Division         Carline  \
# 0        2021                Honda                     Acura             NSX
# 1        2021         aston martin  Aston Martin Lagonda Ltd  Vantage Manual
# 2        2021         aston martin  Aston Martin Lagonda Ltd      Vantage V8
# 3        2021  Volkswagen Group of                      Audi              R8
# 4        2021  Volkswagen Group of                      Audi          R8 2WD
#
#   Verify Mfr Cd  Index (Model Type Index)  Eng Displ  # Cyl Transmission  \
# 0           HNX                        39        3.5      6  Auto(AM-S9)
# 1           ASX                         5        4.0      8   Manual(M7)
# 2           ASX                         4        4.0      8     Auto(S8)
# 3           VGA                         5        5.2     10  Auto(AM-S7)
# 4           VGA                         7        5.2     10  Auto(AM-S7)
#
#    City FE (Guide) - Conventional Fuel  ...  City CO2 Rounded Adjusted  \
# 0                                   21  ...                        420
# 1                                   14  ...                        636
# 2                                   18  ...                        494
# 3                                   13  ...                        663
# 4                                   14  ...                        645
#
#    Hwy CO2 Rounded Adjusted  Comb CO2 Rounded Adjusted (as shown on FE Label)  \
# 0                       406                                               420
# 1                       426                                               541
# 2                       364                                               435
# 3                       450                                               567
# 4                       386                                               528
#
#    CO2-PHEV Composite Rounded Adjusted Combined CO2  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    240V Charge Time at 240 volts (hours)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    120V Charge time at 120 Volts (hours)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    PHEV Total Driving Range (rounded to nearest 10 miles)DISTANCE  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    City PHEV Composite MPGe Hwy PHEV Composite MPGe Comb PHEV Composite MPGe
# 0                       NaN                     NaN                      NaN
# 1                       NaN                     NaN                      NaN
# 2                       NaN                     NaN                      NaN
# 3                       NaN                     NaN                      NaN
# 4                       NaN                     NaN                      NaN
#
# [5 rows x 162 columns]

# %%
# Complete US Fuel Economy Data 2020
excel_file = "complete_us_fuel_economy/2020 FE Guide-adds and corrections for DOE-OK for release-no-sales- 4-7-2021forpublic.xlsx"
car_stats_2020 = pd.read_excel(excel_file)
car_stats_2020.head()
# Out:
#    Model Year             Mfr Name                  Division         Carline  \
# 0        2020                Honda                     Acura             NSX
# 1        2020           FCA US LLC                ALFA ROMEO              4C
# 2        2020         aston martin  Aston Martin Lagonda Ltd  Vantage Manual
# 3        2020         aston martin  Aston Martin Lagonda Ltd      Vantage V8
# 4        2020  Volkswagen Group of                      Audi              R8
#
#   Verify Mfr Cd  Index (Model Type Index)  Eng Displ  # Cyl Transmission  \
# 0           HNX                        55        3.5      6  Auto(AM-S9)
# 1           CRX                       401        1.8      4    Auto(AM6)
# 2           ASX                         5        4.0      8   Manual(M7)
# 3           ASX                         4        4.0      8     Auto(S8)
# 4           VGA                         1        5.2     10  Auto(AM-S7)
#
#    City FE (Guide) - Conventional Fuel  ...  City CO2 Rounded Adjusted  \
# 0                                   21  ...                        420
# 1                                   24  ...                        365
# 2                                   14  ...                        636
# 3                                   18  ...                        494
# 4                                   13  ...                        657
#
#    Hwy CO2 Rounded Adjusted  Comb CO2 Rounded Adjusted (as shown on FE Label)  \
# 0                       406                                               420
# 1                       259                                               317
# 2                       425                                               541
# 3                       364                                               435
# 4                       432                                               556
#
#    CO2-PHEV Composite Rounded Adjusted Combined CO2  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    240V Charge Time at 240 volts (hours)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    120V Charge time at 120 Volts (hours)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    PHEV Total Driving Range (rounded to nearest 10 miles)DISTANCE  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    City PHEV Composite MPGe Hwy PHEV Composite MPGe Comb PHEV Composite MPGe
# 0                       NaN                     NaN                      NaN
# 1                       NaN                     NaN                      NaN
# 2                       NaN                     NaN                      NaN
# 3                       NaN                     NaN                      NaN
# 4                       NaN                     NaN                      NaN
#
# [5 rows x 162 columns]

# %%
# Complete US Fuel Economy Data 2019
excel_file = "complete_us_fuel_economy/2019 FE Guide-for DOE-release dates before 12-19-2019-no-sales- 12_17_2019McLarenpublic.xlsx"
car_stats_2019 = pd.read_excel(excel_file)
car_stats_2019.head()
# Out:
#    Model Year             Mfr Name                  Division  \
# 0        2019                Honda                     Acura
# 1        2019           FCA US LLC                ALFA ROMEO
# 2        2019         aston martin  Aston Martin Lagonda Ltd
# 3        2019  Volkswagen Group of                      Audi
# 4        2019                  BMW                       BMW
#
#                Carline Verify Mfr Cd  Index (Model Type Index)  Eng Displ  \
# 0                  NSX           HNX                        41        3.5
# 1                   4C           CRX                       403        1.8
# 2           Vantage V8           ASX                         3        4.0
# 3  TT Roadster quattro           VGA                        51        2.0
# 4         Z4 sDrive30i           BMX                       350        2.0
#
#    # Cyl Transmission  City FE (Guide) - Conventional Fuel  ...  \
# 0      6  Auto(AM-S9)                                   21  ...
# 1      4    Auto(AM6)                                   24  ...
# 2      8     Auto(S8)                                   18  ...
# 3      4  Auto(AM-S7)                                   23  ...
# 4      4     Auto(S8)                                   25  ...
#
#    City CO2 Rounded Adjusted  Hwy CO2 Rounded Adjusted  \
# 0                        419                       406
# 1                        365                       259
# 2                        494                       364
# 3                        384                       285
# 4                        355                       278
#
#    Comb CO2 Rounded Adjusted (as shown on FE Label)  \
# 0                                               420
# 1                                               317
# 2                                               435
# 3                                               340
# 4                                               321
#
#    CO2-PHEV Composite Rounded Adjusted Combined CO2  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    240V Charge Time at 240 volts (hours)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    120V Charge time at 120 Volts (hours)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    PHEV Total Driving Range (rounded to nearest 10 miles)DISTANCE  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    City PHEV Composite MPGe Hwy PHEV Composite MPGe Comb PHEV Composite MPGe
# 0                       NaN                     NaN                      NaN
# 1                       NaN                     NaN                      NaN
# 2                       NaN                     NaN                      NaN
# 3                       NaN                     NaN                      NaN
# 4                       NaN                     NaN                      NaN
#
# [5 rows x 162 columns]

# %%
# Complete US Fuel Economy Data 2018
excel_file = "complete_us_fuel_economy/2018 FE Guide for DOE3 -all rel dates-no-sales-3-25-2019McLarenforpublic.xlsx"
car_stats_2018 = pd.read_excel(excel_file)
car_stats_2018.head()
# Out:
#    Model Year      Mfr Name                  Division                 Carline  \
# 0        2018  aston martin  Aston Martin Lagonda Ltd                DB11 V12
# 1        2018  aston martin  Aston Martin Lagonda Ltd                 DB11 V8
# 2        2018  aston martin  Aston Martin Lagonda Ltd  Vanquish, S and Zagato
# 3        2018  aston martin  Aston Martin Lagonda Ltd                Rapide S
# 4        2018           BMW                      Mini          COOPER CLUBMAN
#
#   Verify Mfr Cd  Index (Model Type Index)  Eng Displ  # Cyl Transmission  \
# 0           ASX                         1        5.2     12     Auto(S8)
# 1           ASX                         2        4.0      8     Auto(S8)
# 2           ASX                         4        6.0     12     Auto(S8)
# 3           ASX                         5        6.0     12     Auto(S8)
# 4           BMX                        30        1.5      3     Auto(S6)
#
#    City FE (Guide) - Conventional Fuel  ...  City CO2 Rounded Adjusted  \
# 0                                   15  ...                        579
# 1                                   18  ...                        486
# 2                                   13  ...                        659
# 3                                   14  ...                        631
# 4                                   24  ...                        363
#
#    Hwy CO2 Rounded Adjusted  Comb CO2 Rounded Adjusted (as shown on FE Label)  \
# 0                       397                                               497
# 1                       365                                               431
# 2                       428                                               555
# 3                       413                                               533
# 4                       274                                               323
#
#    CO2-PHEV Composite Rounded Adjusted Combined CO2  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    240V Charge Time at 240 volts (hours)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    120V Charge time at 120 Volts (hours)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    PHEV Total Driving Range (rounded to nearest 10 miles)DISTANCE  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    City PHEV Composite MPGe Hwy PHEV Composite MPGe Comb PHEV Composite MPGe
# 0                       NaN                     NaN                      NaN
# 1                       NaN                     NaN                      NaN
# 2                       NaN                     NaN                      NaN
# 3                       NaN                     NaN                      NaN
# 4                       NaN                     NaN                      NaN
#
# [5 rows x 162 columns]

# %%
# Complete US Fuel Economy Data 2017
excel_file = "complete_us_fuel_economy/2017 FE Guide for DOE-release dates before 3-25-2019-no sales-9-19-2019McLarenforpublic.xlsx"
car_stats_2017 = pd.read_excel(excel_file)
car_stats_2017.head()
# Out:
#    Model Year             Mfr Name                  Division        Carline  \
# 0        2017                Honda                     Acura            NSX
# 1        2017           FCA US LLC                ALFA ROMEO             4C
# 2        2017         aston martin  Aston Martin Lagonda Ltd  V12 Vantage S
# 3        2017         aston martin  Aston Martin Lagonda Ltd  V12 Vantage S
# 4        2017  Volkswagen Group of                      Audi             R8
#
#   Verify Mfr Cd  Index (Model Type Index)  Eng Displ  # Cyl Transmission  \
# 0           HNX                         3        3.5      6  Auto(AM-S9)
# 1           CRX                        36        1.8      4    Auto(AM6)
# 2           ASX                         2        6.0     12    Auto(AM7)
# 3           ASX                         3        6.0     12   Manual(M7)
# 4           VGA                         3        5.2     10  Auto(AM-S7)
#
#    City FE (Guide) - Conventional Fuel  ...  City CO2 Rounded Adjusted  \
# 0                                   21  ...                        419
# 1                                   24  ...                        365
# 2                                   12  ...                        737
# 3                                   10  ...                        873
# 4                                   14  ...                        609
#
#    Hwy CO2 Rounded Adjusted  Comb CO2 Rounded Adjusted (as shown on FE Label)  \
# 0                       406                                               420
# 1                       259                                               317
# 2                       485                                               624
# 3                       541                                               724
# 4                       409                                               519
#
#    CO2-PHEV Composite Rounded Adjusted Combined CO2  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    240V Charge Time at 240 volts (hours)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    120V Charge time at 120 Volts (hours)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    PHEV Total Driving Range (rounded to nearest 10 miles)DISTANCE  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    City PHEV Composite MPGe Hwy PHEV Composite MPGe Comb PHEV Composite MPGe
# 0                       NaN                     NaN                      NaN
# 1                       NaN                     NaN                      NaN
# 2                       NaN                     NaN                      NaN
# 3                       NaN                     NaN                      NaN
# 4                       NaN                     NaN                      NaN
#
# [5 rows x 162 columns]

# %%
car_stats_2017_clean = car_stats_2017.loc[:,["Model Year","Mfr Name","Division","City FE (Guide) - Conventional Fuel",
                                             "Hwy FE (Guide) - Conventional Fuel","Comb FE (Guide) - Conventional Fuel",
                                            "City Unadj FE - Conventional Fuel","Hwy Unadj FE - Conventional Fuel","Comb Unadj FE - Conventional Fuel",
                                            "City Unrd Adj FE - Conventional Fuel","Hwy Unrd Adj FE - Conventional Fuel","Comb Unrd Adj FE - Conventional Fuel",
                                            "Guzzler?","Fuel Usage Desc - Conventional Fuel"]]
car_stats_2017_clean.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/pr/1_6x41cj4bg9v9n2y7ppnzyc0000gn/T/ipykernel_83091/1237681445.py in <module>
#       3                                             "City Unadj FE - Conventional Fuel","Hwy Unadj FE - Conventional Fuel","Comb Unadj FE - Conventional Fuel",
#       4                                             "City Unrd Adj FE - Conventional Fuel","Hwy Unrd Adj FE - Conventional Fuel","Comb Unrd Adj FE - Conventional Fuel",
# ----> 5                                             "Guzzler?","Fuel Usage Desc - Conventional Fuel"]]
#       6 car_stats_2017_clean.head()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['Guzzler?'] not in index"
